# %%
import pandas as pd
import numpy as np
a=pd.read_csv("E:/Petplan/10-9 absolute final tree/rules302-5split.csv")
b= pd.DataFrame(columns=['LossRatio'])
for i in range(len(a)):
    j=0
    while((j<len(a.columns))):
        if(str(a.ix[i][j])=='is'):
            b.loc[i,str(a.ix[i][j-1])]=str(a.ix[i][j+1])
        j=j+1
    b.loc[i,'LossRatio']=a.loc[i,'LossRatio']
                
b=b.fillna('-')
b.to_html('E:/Petplan/10-9 absolute final tree/overall/overallfilenametobemergedwithcond.html')
b.to_csv('E:/Petplan/10-9 absolute final tree/overall/overallfilenametobemergedwithcond.csv')
import codecs
f=codecs.open("E:/Petplan/10-9 absolute final tree/overall/overallfilenametobemergedwithcond.html", 'r')
print f.read()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LossRatio</th>
#       <th>Claimcodecategory</th>
#       <th>AnnualDedInd</th>
#       <th>ClaimNonCur</th>
#       <th>PetType</th>
#       <th>ClaimCur</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.13</td>
#       <td>None</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.03</td>
#       <td>Accident or Illness</td>
#       <td>PerCondition</td>
#       <td>No</td>
#       <td>Dog</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.66</td>
#       <td>Accident or Illness</td>
#       <td>PerCondition</td>
#       <td>No</td>
#       <td>Cat</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.89</td>
#       <td>Accident or Illness</td>
#       <td>PerCondition</td>
#       <td>Yes</td>
# ...

# %%
b
# Out:
#    LossRatio    Claimcodecategory  AnnualDedInd ClaimNonCur PetType ClaimCur
# 0       0.13                 None             -           -       -        -
# 1       1.03  Accident or Illness  PerCondition          No     Dog        -
# 2       1.66  Accident or Illness  PerCondition          No     Cat        -
# 3       1.89  Accident or Illness  PerCondition         Yes       -       No
# 4       2.71  Accident or Illness  PerCondition         Yes       -      Yes
# 5       3.08  Accident or Illness        Annual           -       -        -
