# %%
import pandas as pd
import numpy as np
a=pd.read_csv("E:/Petplan/rules.csv")
b= pd.DataFrame(columns=['LossRatio'])
for i in range(len(a)):
    j=0
    while((j<len(a.columns))):
        if(str(a.ix[i][j])=='is'):
            b.loc[i,str(a.ix[i][j-1])]=str(a.ix[i][j+1])
        j=j+1
    b.loc[i,'LossRatio']=a.loc[i,'LossRatio']
                
b=b.fillna('-')
b
# Out:
#    LossRatio Unnamed: 1 Unnamed: 2 Unnamed: 3              Unnamed: 4  \
# 0       0.14       when   Severity         is                    None
# 1       1.27       when   Severity         is                 Curable
# 2       1.99       when   Severity         is             Non-Curable
# 3       2.66       when   Severity         is  Curable or Non-Curable
# 4       4.72       when   Severity         is  Curable or Non-Curable
# 5       5.05       when   Severity         is  Curable or Non-Curable
# 6       8.15       when   Severity         is  Curable or Non-Curable
#
#   Unnamed: 5                Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN                       NaN        NaN        NaN        NaN
# 1          &  claimdurationInception60         is         No        NaN
# 2          &  claimdurationInception60         is         No        NaN
# 3          &  claimdurationInception60         is        Yes          &
# 4          &  claimdurationInception60         is        Yes          &
# 5          &  claimdurationInception60         is        Yes          &
# 6          &  claimdurationInception60         is        Yes          &
#
#       ...     Unnamed: 11 Unnamed: 12  Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0     ...             NaN         NaN          NaN         NaN         NaN
# 1     ...             NaN         NaN          NaN         NaN         NaN
# 2     ...             NaN         NaN          NaN         NaN         NaN
# 3     ...              <          4.1          NaN         NaN         NaN
# 4     ...              >=         4.1            &         Age          <
# 5     ...              <          4.1          NaN         NaN         NaN
# 6     ...              >=         4.1            &         Age          >=
#
#   Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 0         NaN          NaN         NaN         NaN         NaN
# 1         NaN          NaN         NaN         NaN         NaN
# 2         NaN          NaN         NaN         NaN         NaN
# 3         NaN            &     PetType          is         Dog
# 4         6.0          NaN         NaN         NaN         NaN
# 5         NaN            &     PetType          is         Cat
# 6         6.0          NaN         NaN         NaN         NaN
#
# [7 rows x 21 columns]
