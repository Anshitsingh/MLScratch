# %%
import pandas as pd
import numpy as np
a=pd.read_csv("E:/Petplan/rules.csv")
b= pd.DataFrame(columns=['LossRatio'])
for i in range(len(a)):
    j=0
    while((j<len(a.columns))):
        if(str(a.ix[i][j])=='is'):
            b.loc[i,str(a.ix[i][j-1])]=str(a.ix[i][j+1])
        j=j+1
    b.loc[i,'LossRatio']=a.loc[i,'LossRatio']
                
b=b.fillna('-')
b.to_html('E:/Petplan/filename.html')
import codecs
f=codecs.open("E:/Petplan/filename.html", 'r')
print f.read()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LossRatio</th>
#       <th>Severity</th>
#       <th>claimdurationInception60</th>
#       <th>PetType</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.14</td>
#       <td>None</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.27</td>
#       <td>Curable</td>
#       <td>No</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.99</td>
#       <td>Non-Curable</td>
#       <td>No</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.66</td>
#       <td>Curable or Non-Curable</td>
#       <td>Yes</td>
#       <td>Dog</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.72</td>
#       <td>Curable or Non-Curable</td>
#       <td>Yes</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.05</td>
#       <td>Curable or Non-Curable</td>
#       <td>Yes</td>
#       <td>Cat</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>8.15</td>
#       <td>Curable or Non-Curable</td>
#       <td>Yes</td>
#       <td>-</td>
#     </tr>
#   </tbody>
# </table>
# c:\program files (x86)\python27\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# c:\program files (x86)\python27\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':

# %%
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LossRatio</th>
#       <th>Severity</th>
#       <th>claimdurationInception60</th>
#       <th>PetType</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.14</td>
#       <td>None</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.27</td>
#       <td>Curable</td>
#       <td>No</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.99</td>
#       <td>Non-Curable</td>
#       <td>No</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.66</td>
#       <td>Curable or Non-Curable</td>
#       <td>Yes</td>
#       <td>Dog</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.72</td>
#       <td>Curable or Non-Curable</td>
#       <td>Yes</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.05</td>
#       <td>Curable or Non-Curable</td>
#       <td>Yes</td>
#       <td>Cat</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>8.15</td>
#       <td>Curable or Non-Curable</td>
#       <td>Yes</td>
#       <td>-</td>
#     </tr>
#   </tbody>
# </table>

# %%
c
# Out:
#        <table border="1" class="dataframe">
# 0                                   <thead>
# 1           <tr style="text-align: right;">
# 2                                 <th></th>
# 3                        <th>LossRatio</th>
# 4                         <th>Severity</th>
# 5         <th>claimdurationInception60</th>
# 6                          <th>PetType</th>
# 7                                     </tr>
# 8                                  </thead>
# 9                                   <tbody>
# 10                                     <tr>
# 11                               <th>0</th>
# 12                            <td>0.14</td>
# 13                            <td>None</td>
# 14                               <td>-</td>
# 15                               <td>-</td>
# 16                                    </tr>
# 17                                     <tr>
# 18                               <th>1</th>
# 19                            <td>1.27</td>
# 20                         <td>Curable</td>
# 21                              <td>No</td>
# 22                               <td>-</td>
# 23                                    </tr>
# 24                                     <tr>
# 25                               <th>2</th>
# 26                            <td>1.99</td>
# 27                     <td>Non-Curable</td>
# 28                              <td>No</td>
# 29                               <td>-</td>
# ..                                      ...
# 31                                     <tr>
# 32                               <th>3</th>
# 33                            <td>2.66</td>
# 34          <td>Curable or Non-Curable</td>
# 35                             <td>Yes</td>
# 36                             <td>Dog</td>
# 37                                    </tr>
# 38                                     <tr>
# 39                               <th>4</th>
# 40                            <td>4.72</td>
# 41          <td>Curable or Non-Curable</td>
# 42                             <td>Yes</td>
# 43                               <td>-</td>
# 44                                    </tr>
# 45                                     <tr>
# 46                               <th>5</th>
# 47                            <td>5.05</td>
# 48          <td>Curable or Non-Curable</td>
# 49                             <td>Yes</td>
# 50                             <td>Cat</td>
# 51                                    </tr>
# 52                                     <tr>
# 53                               <th>6</th>
# 54                            <td>8.15</td>
# 55          <td>Curable or Non-Curable</td>
# 56                             <td>Yes</td>
# 57                               <td>-</td>
# 58                                    </tr>
# 59                                 </tbody>
# 60                                 </table>
#
# [61 rows x 1 columns]
